# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
data=pd.read_csv("Sample - Superstore.csv",encoding="windows-1252")
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# Check the data types and for missing values
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.ndim
# Out:
# 2

# %%
data.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# General statistics of numerical columns
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# Sales distribution by category
category_sales = data.groupby('Category').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Profit', 'sum')
).reset_index()

# Sales distribution by region
region_sales = data.groupby('Region').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Profit=('Profit', 'sum')
).reset_index()

# Display the results
print(category_sales)
print(region_sales)
# Out:
#           Category  Total_Sales  Total_Profit
# 0        Furniture  741999.7953    18451.2728
# 1  Office Supplies  719047.0320   122490.8008
# 2       Technology  836154.0330   145454.9481
#     Region  Total_Sales  Total_Profit
# 0  Central  501239.8908    39706.3625
# 1     East  678781.2400    91522.7800
# 2    South  391721.9050    46749.4303
# 3     West  725457.8245   108418.4489

# %%
import matplotlib.pyplot as plt

# Convert 'Order Date' to datetime format
data['Order Date'] = pd.to_datetime(data['Order Date'])

# Set the 'Order Date' as the index
data.set_index('Order Date', inplace=True)

# Resample by month and calculate total sales
monthly_sales = data['Sales'].resample('M').sum()

# Plot monthly sales trends
plt.figure(figsize=(10, 6))
monthly_sales.plot()
plt.title('Monthly Sales Trend')
plt.ylabel('Sales')
plt.show()

# %%
# Total sales by customer
customer_sales = data.groupby('Customer ID').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Orders=('Order ID', 'nunique')
).reset_index()

# Display the top 10 customers based on total sales
top_customers = customer_sales.sort_values(by='Total_Sales', ascending=False).head(10)
print(top_customers)
# Out:
#     Customer ID  Total_Sales  Total_Orders
# 700    SM-20320    25043.050             5
# 741    TC-20980    19052.218             5
# 621    RB-19360    15117.339             6
# 730    TA-21385    14595.620             4
# 6      AB-10105    14473.571            10
# 434    KL-16645    14175.229            12
# 669    SC-20095    14142.334             9
# 327    HL-15040    12873.298             6
# 683    SE-20110    12209.438            11
# 131    CC-12370    12129.072             5

# %%
# Top products by sales and quantity
product_sales = data.groupby('Product Name').agg(
    Total_Sales=('Sales', 'sum'),
    Total_Quantity=('Quantity', 'sum')
).reset_index()

# Top 10 products by sales
top_products_sales = product_sales.sort_values(by='Total_Sales', ascending=False).head(10)

# Top 10 products by quantity
top_products_quantity = product_sales.sort_values(by='Total_Quantity', ascending=False).head(10)

print(top_products_sales)
print(top_products_quantity)
# Out:
#                                           Product Name  Total_Sales  \
# 404              Canon imageCLASS 2200 Advanced Copier    61599.824
# 650  Fellowes PB500 Electric Punch Plastic Comb Bin...    27453.384
# 444  Cisco TelePresence System EX90 Videoconferenci...    22638.480
# 786       HON 5400 Series Task Chairs for Big and Tall    21870.576
# 686         GBC DocuBind TL300 Electric Binding System    19823.479
# 688   GBC Ibimaster 500 Manual ProClick Binding System    19024.500
# 805               Hewlett Packard LaserJet 3310 Copier    18839.686
# 787  HP Designjet T520 Inkjet Large Format Printer ...    18374.895
# 683          GBC DocuBind P400 Electric Binding System    17965.068
# 813        High Speed Automatic Electric Letter Opener    17030.312
#
#      Total_Quantity
# 404              20
# 650              31
# 444               6
# 786              39
# 686              37
# 688              48
# 805              38
# 787              12
# 683              27
# ...

# %%
# Bar plot for Sales by Category
plt.figure(figsize=(8,6))
sns.barplot(x='Category', y='Total_Sales', data=category_sales, palette='Blues_d')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
# Bar plot for Profit by Category
plt.figure(figsize=(8,6))
sns.barplot(x='Category', y='Total_Profit', data=category_sales, palette='Greens_d')
plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Total Profit')
plt.show()

# %%
# Bar plot for Sales by Region
plt.figure(figsize=(8,6))
sns.barplot(x='Region', y='Total_Sales', data=region_sales, palette='Purples_d')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()

# %%
# Bar plot for Profit by Region
plt.figure(figsize=(8,6))
sns.barplot(x='Region', y='Total_Profit', data=region_sales, palette='Blues_d')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.show()

# %%
plt.figure(figsize=(7, 7))
region_sales_pie = region_sales.set_index('Region')['Total_Sales']
region_sales_pie.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set2', legend=False)
plt.title('Sales Distribution by Region')
plt.ylabel('')
plt.show()

# %%
category_sales.set_index('Category')[['Total_Sales', 'Total_Profit']].plot(kind='bar', stacked=True)
plt.title('Total Sales and Profit by Category')
plt.ylabel('Amount')
plt.show()
